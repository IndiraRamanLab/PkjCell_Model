# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import math
import os
import warnings
warnings.filterwarnings('ignore')


sns.set(style = "whitegrid", font_scale = 1.5, font = 'arial')
sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
#Point this path to the 'pickle files for analysis' folder.
os.chdir(r'C:\Users\cvaaga\Desktop\Active - Pkj Cell Modeling\Resubmission - Pickle Files for Analysis')

# %% [markdown]
# Graphing and analysis of data presented in figure 1C Top and 1C Bottom

# %%
num_trials = 5000 - 1 #subtract 1 in order to use for loop logic

mli_alone = pickle.load(open('Model1_GPF0_GMLI1', 'rb'))
pf_2_mli_1 = pickle.load(open('Model2_GPF2_GMLI1', 'rb'))


all_runs = [mli_alone, pf_2_mli_1]

for i in range(len(all_runs)):
    all_runs[i] = all_runs[i] - 200

#Histogram (2 ms bins) of well-timed stellate cell inhibition:
plt.figure(1,figsize = (4.8,4))
ax = plt.subplot(111)
labels = ['GPF:GMLI 0:1', 'GPF:GMLI 2:1']
color = ['red', 'black']
for i in range(len(all_runs)):
    sns.distplot(all_runs[i],bins = np.linspace(-200,100,151),kde=False, label = labels[i], 
        color = color[i],hist_kws=dict(alpha=1, linewidth = 1.5, histtype = 'step'))
plt.legend(facecolor = 'white', fontsize = 'xx-small', loc = 1, ncol = 2)

plt.xlim([-50,100])
plt.ylabel('Firing Rate (2 ms bins)')
plt.xticks([-50, -25,  0, 25, 50, 75, 100])
ytick_loc = np.array([0, 250, 500, 750, 1000], dtype = 'int')
plt.yticks(ytick_loc,ytick_loc/(num_trials +1)*500)
plt.xlabel('Time (ms)')
plt.axvline(0,color = 'black', linewidth = 1, linestyle = '--')
frame1 = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
frame1.axes.get_xaxis().set_visible(True)
plt.tight_layout()
plt.savefig('PF_Well_timed_lowconductance.pdf',transparent = True, dpi = 300)



            
##GPF:GMLI > 4:1    
pf_4_mli_1 = pickle.load(open('Model3_GPF4_GMLI1', 'rb'))
pf_6_mli_1 = pickle.load(open('Model4_GPF6_GMLI1', 'rb'))

all_runs = [pf_4_mli_1, pf_6_mli_1]

for i in range(len(all_runs)):
    all_runs[i] = all_runs[i] - 200            
            
plt.figure(2,figsize = (4.8,4))
ax = plt.subplot(111)
labels = ['GPF:GMLI 4:1', 'GPF:GMLI 6:1']
color = ['red', 'black']
for i in range(len(all_runs)):
    sns.distplot(all_runs[i],bins = np.linspace(-200,100,151),kde=False, label = labels[i], 
        color = color[i],hist_kws=dict(alpha=1, linewidth = 1.5, histtype = 'step'))
plt.legend(facecolor = 'white', fontsize = 'xx-small', loc = 1, ncol = 2)

plt.xlim([-50,100])
plt.ylabel('Firing Rate (2 ms bins)')
plt.xticks([-50, -25,  0, 25, 50, 75, 100])
ytick_loc = np.array([0, 250, 500, 750, 1000], dtype = 'int')
plt.yticks(ytick_loc,ytick_loc/(num_trials +1)*500)
plt.xlabel('Time (ms)')
plt.axvline(0,color = 'black', linewidth = 1, linestyle = '--')
frame1 = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
frame1.axes.get_xaxis().set_visible(True)
plt.tight_layout()
plt.savefig('PF_Well_timed_highconductance.pdf',transparent = True, dpi = 300)
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %%
num_trials = 5000 - 1 #subtract 1 in order to use for loop logic

pf_4_mli_2 = pickle.load(open('Model5_GPF4_GMLI2', 'rb'))
pf_8_mli_2 = pickle.load(open('Model6_GPF8_GMLI2', 'rb'))
pf_12_mli_2 = pickle.load(open('Model7_GPF12_GMLI2', 'rb'))


all_runs = [pf_4_mli_2, pf_8_mli_2, pf_12_mli_2]

for i in range(len(all_runs)):
    all_runs[i] = all_runs[i] - 200


#Histogram (2 ms bins) of well-timed stellate cell inhibition:
plt.figure(1,figsize = (4.8, 4))
ax = plt.subplot(111)
labels = ['GPF:GMLI 4:2', 'GPF:GMLI 8:2', 'GPF:GMLI 12:2']
color = ['red', 'black', 'blue']

for i in range(len(all_runs)):
        sns.distplot(all_runs[i],bins = np.linspace(-200,100,151),kde=False, label = labels[i], 
                     color = color[i],hist_kws=dict(alpha=1, linewidth = 1.5, histtype = 'step'))
plt.legend(facecolor = 'white', fontsize = 'xx-small', loc = 1, ncol = 2)

plt.xlim([-50,100])
plt.ylabel('Firing Rate (2 ms bins)')
plt.xticks([-50, -25, 0, 25, 50, 75, 100])
ytick_loc = np.array([0, 250, 500, 750, 1000], dtype = 'int')
plt.yticks(ytick_loc,ytick_loc/(num_trials +1)*500)
plt.xlabel('Time (ms)')
plt.axvline(0,color = 'black', linewidth = 1, linestyle = '--')
frame1 = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
frame1.axes.get_xaxis().set_visible(True)
plt.tight_layout()
plt.savefig('double_conductance.pdf',transparent = True, dpi = 300)



## Half MLI Conductance
pf_1_mli_half = pickle.load(open('Model17_GPF1_GMLIhalf','rb'))
pf_2_mli_half = pickle.load(open('Model8_GPF2_GMLIhalf', 'rb'))
pf_3_mli_half = pickle.load(open('Model9_GPF3_GMLIhalf', 'rb'))


all_runs = [pf_1_mli_half, pf_2_mli_half, pf_3_mli_half]

for i in range(len(all_runs)):
    all_runs[i] = all_runs[i] - 200

plt.figure(2,figsize = (4.6,4))
ax = plt.subplot(111)
labels = ['GPF:GMLI 1:0.5', 'GPF:GMLI 2:0.5', 'GPF:GMLI 3:0.5']
color = ['red', 'black', 'blue']
for i in range(len(all_runs)):
    sns.distplot(all_runs[i], bins = np.linspace(-200,100,151),kde=False, label = labels[i], 
        color = color[i],hist_kws=dict(alpha=1, linewidth = 1.5, histtype = 'step'))
plt.legend(facecolor = 'white', fontsize = 'xx-small', loc = 1, ncol = 2)

plt.xlim([-50, 100])
plt.ylabel('Firing Rate (2 ms bins)')
plt.xticks([-50, -25, 0, 25, 50, 75, 100])
ytick_loc = np.array([0, 250, 500, 750, 1000], dtype = 'int')
plt.yticks(ytick_loc,ytick_loc/(num_trials +1)*500)
plt.xlabel('Time (ms)')
plt.axvline(0,color = 'black', linewidth = 1, linestyle = '--')
frame1 = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
frame1.axes.get_xaxis().set_visible(True)
plt.tight_layout()
plt.savefig('Half_MLI_Conductance',transparent = True, dpi = 300)
# Out:
# meta NOT subset; don't know how to subset; dropped

# %%
# Suppression and Elevation Analysis - Normal Conductance


all_runs = [mli_alone, pf_2_mli_1, pf_4_mli_1, pf_6_mli_1, 
            pf_4_mli_2, pf_8_mli_2, pf_12_mli_2,
            pf_1_mli_half, pf_2_mli_half, pf_3_mli_half]


for i in range(len(all_runs)):
    all_runs[i] = all_runs[i] - 200

suppression = np.array([])
elevation = np.array([])
mean_mod_ratio = np.array([])
min_mod_ratio = np.array([])
baseline_mean = np.array([])
max_mod_ratio = np.array([])


for i in range(len(all_runs)):
    counts_raw, bins = np.histogram(all_runs[i], np.linspace(-200,100,151))
    counts = np.array(counts_raw/(num_trials +1))

    idx1 = np.where(bins == -50); idx1 = idx1[0].astype('int')
    idx2 = np.where(bins == 20); idx2 = idx2[0].astype('int')
    len_array = idx2-idx1
    data = np.zeros([len_array[0],2])
    data[:,0] = bins[idx1[0]:idx2[0]]
    data[:,1] = counts[idx1[0]:idx2[0]]


    baseline_mean = np.append(baseline_mean, np.mean(data[0:25,1]))
    suppression = np.append(suppression, np.min(data[26:31,1]))
    elevation = np.append(elevation, np.max(data[26:31,1]))


    mean_mod_ratio = np.append(mean_mod_ratio,np.mean(data[26:31,1]) / np.mean(data[0:25,1]))
    min_mod_ratio = np.append(min_mod_ratio,np.min(data[26:31,1]) / np.mean(data[0:25,1]))
    max_mod_ratio = np.append(max_mod_ratio,np.max(data[26:31,1] / np.mean(data[0:25,1])))

mod_depth_minimum = (1 - min_mod_ratio)* -1
mod_depth_maximum = (1 - max_mod_ratio)* -1

summary_data =  {'Model':['0 pf:0 mli1', '2 pf:1 mli', '4 pf:1 mli', '6 pf:1 mli', '4 pf:2 mli', '8 pf:2 mli', '12 pf:2 mli',
                         '1 pf:0.5 mli', '2 pf:0.5 mli', '3 pf:0.5 mli'],
           'Baseline Firing Rate':baseline_mean * 500, 
           'Minimum Firing Rate': suppression *500,
           'Min Delta Rate': (suppression *500) - (baseline_mean*500),
           'Modulation Depth - Min (% Change)': mod_depth_minimum * 100, 
           'Modulation Depth - Max (% Change)': mod_depth_maximum * 100,            }


data_frame = pd.DataFrame.from_dict(summary_data)
data_frame = data_frame.set_index('Model')  

norm_conductance = np.array([mod_depth_minimum, mod_depth_maximum])

data_frame
# Out:
#               Baseline Firing Rate  Minimum Firing Rate  Min Delta Rate  \
# Model
# 0 pf:0 mli1                 62.252                 22.4         -39.852
# 2 pf:1 mli                  62.176                 29.6         -32.576
# 4 pf:1 mli                  61.504                 34.7         -26.804
# 6 pf:1 mli                  61.780                 35.5         -26.280
# 4 pf:2 mli                  61.976                 13.1         -48.876
# 8 pf:2 mli                  62.372                 18.9         -43.472
# 12 pf:2 mli                 62.152                 20.9         -41.252
# 1 pf:0.5 mli                62.024                 42.5         -19.524
# 2 pf:0.5 mli                62.148                 46.7         -15.448
# 3 pf:0.5 mli                62.328                 46.1         -16.228
#
#               Modulation Depth - Min (% Change)  \
# Model
# 0 pf:0 mli1                          -64.017220
# 2 pf:1 mli                           -52.393206
# 4 pf:1 mli                           -43.580905
# 6 pf:1 mli                           -42.538038
# 4 pf:2 mli                           -78.862786
# 8 pf:2 mli                           -69.697941
# 12 pf:2 mli                          -66.372764
# 1 pf:0.5 mli                         -31.478137
# 2 pf:0.5 mli                         -24.856793
# 3 pf:0.5 mli                         -26.036452
#
#               Modulation Depth - Max (% Change)
# Model
# 0 pf:0 mli1                          -24.821692
# 2 pf:1 mli                             6.471951
# 4 pf:1 mli                            18.041103
# 6 pf:1 mli                            29.653610
# 4 pf:2 mli                            10.849361
# 8 pf:2 mli                            37.080741
# 12 pf:2 mli                           67.975286
# 1 pf:0.5 mli                          -2.134658
# 2 pf:0.5 mli                           2.014546
# 3 pf:0.5 mli                          21.293801

# %%
# Burst E alone and EI coupled at 1:1 and 4:1

burst_alone = pickle.load(open('Model10_GPF_Burst_Eonly', 'rb'))
burst_GPF_2_GMLI_1 = pickle.load(open('Model16_GPF_Burst_Welltimed_2GPF1GMLI', 'rb'))
burst_ei_1 = pickle.load(open('Model11_GPF1_GMLI1_Burst_coupled', 'rb'))
burst_ei_4 = pickle.load(open('Model12_GPF4_GMLI1_Burst_coupled', 'rb'))

all_runs = [burst_alone, burst_GPF_2_GMLI_1, burst_ei_1, burst_ei_4]

for i in range(len(all_runs)):
    all_runs[i] = all_runs[i] - 200

plt.figure(2,figsize = (4.6,4))
ax = plt.subplot(111)
#labels = ['GPF:GMLI 2:0.5', 'GPF:GMLI 4:0.5', 'GPF:GMLI 6:0.5']
color = ['black', 'red', 'blue', 'green']
for i in range(len(all_runs)):
    sns.distplot(all_runs[i], bins = np.linspace(-200,100,151),kde=False, 
        color = color[i],hist_kws=dict(alpha=1, linewidth = 1.5, histtype = 'step'))
plt.legend(facecolor = 'white', fontsize = 'xx-small', loc = 1, ncol = 2)

plt.xlim([-100, 100])
plt.ylabel('Firing Rate (2 ms bins)')
plt.xticks([-100, -75, -50, -25, 0, 25, 50, 75, 100])
ytick_loc = np.array([0, 250, 500, 750, 1000], dtype = 'int')
plt.yticks(ytick_loc,ytick_loc/(num_trials +1)*500)
plt.xlabel('Time (ms)')
plt.axvline(0,color = 'black', linewidth = 1, linestyle = '--')
frame1 = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
frame1.axes.get_xaxis().set_visible(True)
plt.tight_layout()
plt.savefig('Burst.pdf',transparent = True, dpi = 300)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# meta NOT subset; don't know how to subset; dropped

# %%
run6 = pickle.load(open('Model15_GoC_50pct', 'rb'))

all_runs = [run6]

for i in range(len(all_runs)):
    all_runs[i] = all_runs[i] - 200

plt.figure(2,figsize = (4.6,4))
ax = plt.subplot(111)
labels = ['GPF:GMLI 1:1 + 5 PF']
color = ['black']
for i in range(len(all_runs)):
    sns.distplot(all_runs[i], bins = np.linspace(-200,100,151),kde=False, label = labels[i], 
        color = color[i],hist_kws=dict(alpha=1, linewidth = 1.5, histtype = 'step'))
plt.legend(facecolor = 'white', fontsize = 'xx-small', loc = 1, ncol = 2)

plt.xlim([-50, 100])
plt.ylabel('Firing Rate (2 ms bins)')
plt.xticks([-50, -25, 0, 25, 50, 75, 100])
ytick_loc = np.array([0, 250, 500, 750, 1000], dtype = 'int')
plt.yticks(ytick_loc,ytick_loc/(num_trials +1)*500)
plt.xlabel('Time (ms)')
plt.axvline(0,color = 'black', linewidth = 1, linestyle = '--')
frame1 = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
frame1.axes.get_xaxis().set_visible(True)
plt.tight_layout()
os.chdir(figure_directory)
plt.savefig('GoC_withdrawal.pdf', transparent = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 29
#      27 frame1.axes.get_xaxis().set_visible(True)
#      28 plt.tight_layout()
# ---> 29 os.chdir(figure_directory)
#      30 plt.savefig('GoC_withdrawal.pdf', transparent = True)
#
# NameError: name 'figure_directory' is not defined

# %%
run6 = pickle.load(open('Model14_GPF_burst_Facilitation', 'rb'))

all_runs = [run6]

for i in range(len(all_runs)):
    all_runs[i] = all_runs[i] - 200

plt.figure(2,figsize = (4.6,4))
ax = plt.subplot(111)
labels = ['GPF:GMLI 1:1 + 5 PF']
color = ['black']
for i in range(len(all_runs)):
    sns.distplot(all_runs[i], bins = np.linspace(-200,100,151),kde=False, label = labels[i], 
        color = color[i],hist_kws=dict(alpha=1, linewidth = 1.5, histtype = 'step'))
plt.legend(facecolor = 'white', fontsize = 'xx-small', loc = 1, ncol = 2)

plt.xlim([-50, 100])
plt.ylabel('Firing Rate (2 ms bins)')
plt.xticks([-50, -25, 0, 25, 50, 75, 100])
ytick_loc = np.array([0, 250, 500, 750, 1000], dtype = 'int')
plt.yticks(ytick_loc,ytick_loc/(num_trials +1)*500)
plt.xlabel('Time (ms)')
for i in range(5):
    delta_t = np.linspace(0,80,5)
    plt.axvline(0+delta_t[i],color = 'black', linewidth = 1, linestyle = '--')

frame1 = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
frame1.axes.get_xaxis().set_visible(True)
plt.tight_layout()
plt.savefig('facilitation.pdf', transparent = True, dpi = 300)
# Out:
# meta NOT subset; don't know how to subset; dropped

# %%
# Burst E alone and EI coupled at 1:1 and 4:1

burst_alone = pickle.load(open('Model10_GPF_Burst_Eonly', 'rb'))
burst_GPF_2_GMLI_1 = pickle.load(open('Model16_GPF_Burst_Welltimed_2GPF1GMLI', 'rb'))
burst_GPF_4_GMLI_1 = pickle.load(open('Model17_GPF_Burst_Welltimed_4GPF1GMLI', 'rb'))

all_runs = [burst_alone, burst_GPF_2_GMLI_1, burst_GPF_4_GMLI_1]

for i in range(len(all_runs)):
    all_runs[i] = all_runs[i] - 200

plt.figure(2,figsize = (4.6,4))
ax = plt.subplot(111)
labels = ['GPF:GMLI 2:0.5', 'GPF:GMLI 4:0.5', 'GPF:GMLI 6:0.5']
color = ['red', 'black', 'blue']
for i in range(len(all_runs)):
    sns.distplot(all_runs[i], bins = np.linspace(-200,100,151),kde=False, label = labels[i], 
        color = color[i],hist_kws=dict(alpha=1, linewidth = 1.5, histtype = 'step'))
plt.legend(facecolor = 'white', fontsize = 'xx-small', loc = 1, ncol = 2)

plt.xlim([-50, 50])
plt.ylabel('Firing Rate (2 ms bins)')
plt.xticks([-100, -75, -50, -25, 0, 25, 50, 75, 100])
ytick_loc = np.array([0, 250, 500, 750, 1000], dtype = 'int')
plt.yticks(ytick_loc,ytick_loc/(num_trials +1)*500)
plt.xlabel('Time (ms)')
plt.axvline(0,color = 'black', linewidth = 1, linestyle = '--')
frame1 = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
frame1.axes.get_xaxis().set_visible(True)
plt.tight_layout()
plt.savefig('Burst_welltimed.pdf',transparent = True, dpi = 300)
# Out:
# meta NOT subset; don't know how to subset; dropped
